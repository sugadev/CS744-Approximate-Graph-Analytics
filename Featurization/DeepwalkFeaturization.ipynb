# %% [markdown]
# # DeepWalk Featurization

# %%
numGraphs = 1252
for i in range(5,numGraphs+1):#first four graphs are empty
    inFile = "graphs_formatted/edges/edge_"+str(i)+".edgelist"
    outFile = "deepwalk_featurized/graph_"+str(i)+".embeddings"
    # !deepwalk --format edgelist --input $inFile --output $outFile --representation-size 10
# Out:
# Number of nodes: 2
# Number of walks: 20
# Data size (walks*length): 800
# Walking...
# Training...
# 2019-04-26 01:10:33 WARNING base_any2vec.py: 723 consider setting layer size to a multiple of 4 for greater performance
# 2019-04-26 01:10:33 WARNING base_any2vec.py: 1386 under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2019-04-26 01:10:33 WARNING smart_open_lib.py: 379 this function is deprecated, use smart_open.open instead
# Number of nodes: 3
# Number of walks: 30
# Data size (walks*length): 1200
# Walking...
# Training...
# 2019-04-26 01:10:34 WARNING base_any2vec.py: 723 consider setting layer size to a multiple of 4 for greater performance
# 2019-04-26 01:10:34 WARNING base_any2vec.py: 1386 under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2019-04-26 01:10:34 WARNING smart_open_lib.py: 379 this function is deprecated, use smart_open.open instead
# Number of nodes: 3
# Number of walks: 30
# ...
